# %%
import pandas as pd
from python_scripts.data_and_descriptives import *
import matplotlib.pyplot as plt
from datetime import date
# %matplotlib inline
plt.rcParams['figure.figsize'] = (16, 9)
plt.style.use('ggplot')

# %%
etf_data = pd.read_excel('etf_data/etf_ib_data.xlsx', header=0)
print(f'duplicated data: {etf_data[etf_data.symbol.duplicated()].symbol}')

freq = "1d"
start = '2024-01-01'
fin = date.today()
rf =  0.0525


etf_types = ['Regional','Sectorial','Factor','Bonds','Alternative','Market','General','Commodities','Currency','ESG','High Dividend']
    

resultados, retornos = data_results(etf_data, start, fin, freq, etf_type=etf_types)
# Out:
# duplicated data: Series([], Name: symbol, dtype: object)
# [*********************100%***********************]  970 of 970 completed
#
# 26 Failed downloads:
# ['DDG', 'EVGBC', 'BAL', 'NIB', 'SUBZ', 'HYLD', 'EDUT', 'KESG', 'RJN', 'KEJI', 'EVSTC', 'SPAK', 'BOSS', 'DGL', 'RJA', 'DBS', 'DBV', 'EVLMC', 'KFYP', 'IXSE', 'EWEB', 'JO', 'DXGE', 'RJI', 'CROC', 'ALFA']: YFPricesMissingError('possibly delisted; no price data found  (1d 2024-01-01 -> 2025-09-18)')
# Total of 85 tickers dropped: {'RJA', 'RESP', 'GERM', 'KMED', 'DDG', 'CHIX', 'EVGBC', 'DBS', 'RESD', 'CHIU', 'KFVG', 'POTX', 'RJN', 'BTCW', 'HEWG', 'LBJ', 'NGE', 'BAL', 'COW', 'THCX', 'RJI', 'PAK', 'CROC', 'RCD', 'DBV', 'AMJ', 'EMFM', 'JJG', 'CHIH', 'NIB', 'SGG', 'KEJI', 'KALL', 'CHII', 'CHIS', 'CHAD', 'PGAL', 'GLCN', 'SPXZ', 'RATE', 'ALFA', 'SUBZ', 'BFIT', 'EVSTC', 'OAIE', 'CYB', 'RUSL', 'EVLMC', 'JJC', 'RAYS', 'MOON', 'SPAK', 'CACG', 'KFYP', 'CHIK', 'PLAT', 'HYLD', 'IXSE', 'OAIA', 'EWEB', 'IBIT', 'SOVB', 'FM', 'CHIE', 'EDUT', 'KBUY', 'WBND', 'OAIB', 'AFTY', 'JO', 'CHIR', 'KESG', 'FBTC', 'RESE', 'BOSS', 'CHIC', 'CHIM', 'KCNY', 'CHB', 'WPS', 'KGRO', 'WINC', 'DGL', 'WNDY', 'DXGE'}               using a threshold of max NA of: 3
# Total of 565 remaining tickers with NA: ['AAXJ', 'ACSI', 'ACWI', 'ACWV', 'ADME', 'AGGY', 'ALTY', 'ANGL', 'ARGT', 'ARKF', 'ARKW', 'ARP', 'ASHR', 'ASHS', 'AUSF', 'AWAY', 'BATT', 'BBH', 'BIB', 'BITQ', 'BIV', 'BJK', 'BKAG', 'BKCH', 'BKLC', 'BKLN', 'BLCN', 'BLV', 'BNDX', 'BNO', 'BOND', 'BRF', 'BRZU', 'BSV', 'BUFR', 'BUG', 'BUZZ', 'BWX', 'BZQ', 'CATH', 'CEFA', 'CEMB', 'CEW', 'CFA', 'CHIQ', 'CIBR', 'CLOU', 'CNBS', 'CNXT', 'COMB', 'COMT', 'COPX', 'CPER', 'CSD', 'CTEC', 'CURE', 'CVY', 'CWB', 'CWI', 'CXSE', 'DAPP', 'DAX', 'DBB', 'DBC', 'DBEU', 'DDLS', 'DEEP', 'DES', 'DEW', 'DFAU', 'DFE', 'DFND', 'DGRW', 'DHS', 'DIG', 'DIM', 'DIVO', 'DIVY', 'DLS', 'DOG', 'DOL', 'DON', 'DOO', 'DPST', 'DRIV', 'DRV', 'DRW', 'DTD', 'DTEC', 'DTH', 'DTN', 'DUG', 'DUSL', 'DWM', 'DWMF', 'DWX', 'DXJ', 'DXJS', 'EBIZ', 'EBND', 'ECH', 'EDC', 'EDOC', 'EDV', 'EDZ', 'EEMV', 'EES', 'EEV', 'EFAS', 'EFAV', 'EFG', 'EFU', 'EFV', 'EFZ', 'EINC', 'ELD', 'EMB', 'EMBD', 'EMCB', 'EMMF', 'ENZL', 'EPI', 'EPS', 'EPV', 'ERUS', 'ERX', 'ERY', 'ESGU', 'ESGV', 'ESPO', 'EUDG', 'EUFN', 'EUM', 'EUO', 'EUSC', 'EVNT', 'EWA', 'EWC', 'EWG', 'EWH', 'EWI', 'EWJ', 'EWK', 'EWL', 'EWM', 'EWN', 'EWQ', 'EWS', 'EWT', 'EWV', 'EWW', 'EWX', 'EWY', 'EYLD', 'EZA', 'EZJ', 'FAN', 'FCA', 'FCG', 'FCOM', 'FCSH', 'FDIS', 'FDL', 'FDMO', 'FENY', 'FEP', 'FEX', 'FHLC', 'FHYS', 'FIDI', 'FINX', 'FIXD', 'FLSP', 'FMAT', 'FNCL', 'FNDE', 'FNDF', 'FNDX', 'FQAL', 'FREL', 'FSMD', 'FSTA', 'FTAG', 'FTC', 'FTCS', 'FTGC', 'FTRB', 'FTSM', 'FUTY', 'FVD', 'FXA', 'FXB', 'FXD', 'FXE', 'FXF', 'FXG', 'FXH', 'FXL', 'FXN', 'FXP', 'FXR', 'FXU', 'FXY', 'FYLD', 'GAA', 'GDMA', 'GHYB', 'GIGB', 'GINN', 'GNR', 'GOEX', 'GOVT', 'GREK', 'GSIE', 'GSLC', 'GSY', 'GUNR', 'GVAL', 'GVI', 'GVIP', 'GWX', 'GXC', 'GXG', 'GXTG', 'GYLD', 'HACK', 'HDV', 'HEDJ', 'HEFA', 'HERO', 'HEZU', 'HIBL', 'HIPS', 'HNDL', 'HTUS', 'HYD', 'HYDR', 'HYMB', 'HYS', 'HYZD', 'IAT', 'IBB', 'IBUY', 'ICF', 'IDNA', 'IDRV', 'IDU', 'IEF', 'IEFA', 'IEMG', 'IEO', 'IEUR', 'IFGL', 'IGE', 'IGF', 'IGIB', 'IGM', 'IGN', 'IGSB', 'IGV', 'IHAK', 'IHDG', 'IHE', 'IHF', 'IHI', 'IHY', 'IJJ', 'IJK', 'IJS', 'ILCG', 'ILCV', 'ILF', 'IMCB', 'INDL', 'INFL', 'INFR', 'INTF', 'IOO', 'IQDF', 'IQDG', 'IRBO', 'ISCB', 'ISRA', 'ISTB', 'ITEQ', 'ITOT', 'IUSB', 'IUSG', 'IUSV', 'IVE', 'IWB', 'IWC', 'IWD', 'IWF', 'IWN', 'IWO', 'IWP', 'IWR', 'IWS', 'IXC', 'IXJ', 'IXP', 'IYE', 'IYH', 'IYR', 'IYZ', 'JETS', 'JHML', 'JNK', 'JPEM', 'JPUS', 'JUST', 'KBA', 'KBE', 'KBWB', 'KBWD', 'KBWY', 'KCCB', 'KCE', 'KEMQ', 'KEMX', 'KGRN', 'KIE', 'KOMP', 'KRBN', 'KRE', 'KRMA', 'KROP', 'KURE', 'LDUR', 'LEAD', 'LEMB', 'LIT', 'LMBS', 'LOUP', 'LQD', 'LQDH', 'LRGF', 'LTPZ', 'LVHD', 'LVHI', 'MAXI', 'MBB', 'MDY', 'MDYG', 'MDYV', 'MFDX', 'MFEM', 'MFUS', 'MGC', 'MGV', 'MIDU', 'MILN', 'MINO', 'MJ', 'MLPA', 'MLPX', 'MOO', 'MORT', 'MUB', 'MUNI', 'MXI', 'MYY', 'MZZ', 'NAIL', 'NERD', 'NOBL', 'NTSX', 'OBOR', 'OEUR', 'OIH', 'ONOF', 'OUNZ', 'OUSA', 'OVLH', 'OVT', 'PAVE', 'PBD', 'PBW', 'PCEF', 'PCY', 'PDBC', 'PDP', 'PEJ', 'PEY', 'PFFD', 'PGJ', 'PHB', 'PHO', 'PID', 'PIE', 'PIN', 'PIZ', 'PJP', 'PKW', 'PNQI', 'PPA', 'PPH', 'PRF', 'PSCE', 'PSCH', 'PSP', 'PST', 'PTLC', 'PUTW', 'PXE', 'QABA', 'QAI', 'QCLR', 'QDIV', 'QQEW', 'QQQE', 'QQQJ', 'QRMI', 'QSY', 'QTR', 'RAFE', 'REGL', 'REM', 'RETL', 'REW', 'REZ', 'RING', 'RLY', 'RNRG', 'RODM', 'ROM', 'RPAR', 'RPV', 'RWJ', 'RWK', 'RWL', 'RWX', 'RXL', 'RYH', 'SAA', 'SBIO', 'SCHC', 'SCHE', 'SCHH', 'SCHK', 'SCHM', 'SCHO', 'SCHP', 'SCHR', 'SCJ', 'SFIG', 'SHAG', 'SHYG', 'SJB', 'SJNK', 'SKYY', 'SLX', 'SMMU', 'SNPE', 'SNSR', 'SOYB', 'SPAB', 'SPCX', 'SPDW', 'SPEM', 'SPHB', 'SPHD', 'SPHQ', 'SPIB', 'SPLV', 'SPMD', 'SPSB', 'SPSM', 'SPTI', 'SPTL', 'SPTM', 'SPTS', 'SPYV', 'SQLV', 'SRET', 'SRVR', 'STIP', 'SVOL', 'SYLD', 'TAGS', 'TBT', 'TDSC', 'TLH', 'TOTL', 'TPOR', 'TTT', 'TUR', 'TYD', 'TYO', 'UCO', 'UDN', 'UFO', 'UGA', 'UNG', 'UNL', 'USD', 'USDU', 'USFR', 'USIG', 'USL', 'USMC', 'USMF', 'UST', 'UUP', 'UYG', 'UYM', 'VAMO', 'VAW', 'VBK', 'VBR', 'VCLT', 'VCSH', 'VDC', 'VDE', 'VEA', 'VFH', 'VGIT', 'VGK', 'VGT', 'VLUE', 'VO', 'VOE', 'VOT', 'VOX', ...
# ratio_metric: estimating sharpe_ratio using target of 0.05
# using RETURNS...
# c:\Users\germa\Documents\Python\dynamic_asset_allocation\python_scripts\data_and_descriptives.py:101: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df = df.fillna(method='backfill')
# c:\Users\germa\Documents\Python\dynamic_asset_allocation\python_scripts\data_and_descriptives.py:817: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   returns = df.pct_change().dropna()

# %%
resultados.head(10)
# Out:
#                                                 fund      type description  \
# EZA                    iShares MSCI South Africa ETF  Regional         NaN
# VEU                Vanguard FTSE All-World ex-US ETF  Regional         NaN
# EWZ                          iShares MSCI Brazil ETF  Regional         NaN
# EET            ProShares Ultra MSCI Emerging Markets  Regional         NaN
# ERUS                         iShares MSCI Russia ETF  Regional         NaN
# IEV                               iShares Europe ETF  Regional         NaN
# ITOT      iShares Core S&P Total US Stock Market ETF  Regional         NaN
# DDM                            ProShares Ultra Dow30  Regional         NaN
# EDZ   Direxion Daily Emerging Markets Bear 3X Shares  Regional         NaN
# SCHB                      Schwab US Broad Market ETF  Regional         NaN
#
#       ib_commission_free short_leveraged            region sector  \
# EZA                  NaN             NaN      south africa    NaN
# VEU                  NaN             NaN      global ex-us    NaN
# EWZ                  NaN             NaN            brazil    NaN
# EET                  NaN       Leveraged  emerging markets    NaN
# ERUS                 NaN             NaN            russia    NaN
# IEV                  NaN             NaN            europe    NaN
# ITOT                 NaN             NaN               usa    NaN
# DDM                  NaN       Leveraged               usa    NaN
# EDZ                  NaN       Leveraged  emerging markets    NaN
# SCHB                 NaN             NaN               usa    NaN
#
#       value_growth  momentum  small_mid_large  ...  high_dividend  \
# EZA            NaN       NaN              NaN  ...            NaN
# VEU            NaN       NaN              NaN  ...            NaN
# EWZ            NaN       NaN              NaN  ...            NaN
# EET            NaN       NaN              NaN  ...            NaN
# ERUS           NaN       NaN              NaN  ...            NaN
# IEV            NaN       NaN              NaN  ...            NaN
# ITOT           NaN       NaN              NaN  ...            NaN
# DDM            NaN       NaN              NaN  ...            NaN
# EDZ            NaN       NaN              NaN  ...            NaN
# SCHB           NaN       NaN              NaN  ...            NaN
#
#       short_intermediate_long_term  corporate  governmental    manager  \
# EZA                            NaN        NaN           NaN    iShares
# VEU                            NaN        NaN           NaN   Vanguard
# EWZ                            NaN        NaN           NaN    iShares
# EET                            NaN        NaN           NaN  ProShares
# ERUS                           NaN        NaN           NaN    iShares
# IEV                            NaN        NaN           NaN    iShares
# ITOT                           NaN        NaN           NaN    iShares
# DDM                            NaN        NaN           NaN  ProShares
# EDZ                            NaN        NaN           NaN   Direxion
# SCHB                           NaN        NaN           NaN     Schwab
#
#       gross_expense_ratio  annualized_returns annualized_volatility  \
# EZA                0.0059             0.32779               0.24591
# VEU                0.0008             0.19172               0.14666
# EWZ                   NaN            -0.00446               0.23121
# EET                   NaN             0.32407               0.33859
# ERUS                  NaN             0.37744               0.41422
# IEV                   NaN             0.16823               0.15444
# ITOT                  NaN             0.22089               0.16915
# DDM                   NaN             0.19697               0.29468
# EDZ                   NaN            -0.43230               0.51355
# SCHB                  NaN             0.22317               0.16633
#
#       sharpe_ratio  max_drawdown
# EZA        1.07606       0.17278
# VEU        0.92048       0.13693
# EWZ       -0.22440       0.29888
# EET        0.77102       0.34890
# ERUS       0.75298      -0.00000
# IEV        0.72923       0.14634
# ITOT       0.96236       0.19440
# DDM        0.47506       0.31624
# EDZ       -0.89460       0.67440
# SCHB       0.99169       0.19344
#
# [10 rows x 23 columns]
